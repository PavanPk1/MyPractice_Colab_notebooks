# %% [markdown]
# <a href="https://colab.research.google.com/github/PavanPk1/MyPractice_Colab_notebooks/blob/main/Hypothesis_Testing(Z_test)_assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Z-Test Coding Practice

# %% [markdown]
# ## **Instructions for Z-Test Coding Practice**
#
# Welcome to the **Z-Test Coding Practice**! In this coding practice, you will perform **hypothesis testing** using the **Z-test** on real-world scenarios. You will determine if sample data significantly differs from population parameters by computing **Z-scores**, **p-values**, and drawing conclusions based on statistical significance. Follow these instructions carefully to complete your coding practice.

# %% [markdown]
# ### **1. Understand the Problem Statement**
# You will be working with various scenarios where hypothesis testing is applied. Each problem involves:
# 1. **Student Weight Test**: Verify whether the average student weight is more than **66 kg**, given a sample of **100 students**.
# 2. **Basketball Team Points**: Test if the average team points for **Chicago Bulls** is **less than 108** based on a sample of **50 matches**.
# 3. **Fighter Jet Takeoff Distance**: Assess whether the minimum takeoff distance for a **fighter aircraft** is **not more than 800 meters**.
# 4. **Product Rating Analysis**: Check if the average rating received by a **company’s product** is **less than 4.2**, using a sample of **20 reviews**.
# 5. **Salt Bag Weight Test**: Verify if a **salt-filling machine** needs recalibration by testing whether the bag weights differ significantly from **1 kg**.
#
# Your task is to **formulate hypotheses, calculate Z-scores, determine p-values, and make statistical conclusions**.
#
#
#
# ### **2. Read Each Question Carefully**
# Each question is designed to test your understanding of **Z-tests**, including:
# - **One-tailed tests** (e.g., upper or lower tail probability calculations).
# - **Two-tailed tests** (e.g., checking for any significant deviation from a mean).
# - **Critical value comparisons** to draw conclusions.
#
# Make sure you understand the hypothesis (**H₀ & H₁**) before running any test.
#
#
#
# ### **3. Write Your Code in the Provided Cells**
# - A **code cell** is provided for each question. Write your Python code in the designated cell.
# - Ensure that you use appropriate **SciPy functions** for Z-score and p-value calculations.
#
#
#
# ### **4. Run Your Code**
# - After writing your code, **run the cell** to check if your calculations are correct.
# - Verify that your output matches expected values.
#
#
#
# ### **5. Debug if Necessary**
# If your results are incorrect:
#    - Review your code for logical errors.
#    - Use additional `print()` statements to inspect calculations.
#    - Ensure correct usage of **Z-test formulas** and **normal distribution functions**.
#
#
#
# ### **6. Complete All Questions**
# - Answer **all the questions** related to **weight analysis, sports performance, aviation, product ratings, and manufacturing quality control**.
# - Each question tests a different aspect of **hypothesis testing** and statistical significance.
#
#
#
# ### **7. Review Your Work**
# Before submission, check that:
#    - All **hypotheses are correctly stated** (**H₀ & H₁**).
#    - Calculations are **correct and properly formatted**.
#    - Results are **clear and meaningful**.
#    - The code runs without errors.
#
#
#
# ### **8. Download Your Notebook**
# - Once completed, **download your notebook file (`.ipynb`)** by navigating to:
#   **File > Download > Download `.ipynb`**.
#
#
#
# ### **9. Submit Your Coding Practice**
# - Upload the **downloaded `.ipynb` file** to the designated learning platform.
#
#
#
# ### **10. Verify Submission**
# Double-check your submission to ensure:
#    - The uploaded file is correct.
#    - There are no **missing answers or errors**.
#    - If any issues arise, re-upload the correct file.
#
# ---
#
# **Good luck with your Z-Test Coding Practice! 🚀**

# %%
# Run this code cell
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %% [markdown]
# **For each problem assume the significance level to be 0.05 unless specified**

# %% [markdown]
# ---
# ---
# **1. The average weight of students in an undergraduate college was reported to be 66kg with a standard deviation of 15.To verify this claim 100 students were selected at random, their weights are given below. Verify whether the average weight is more than the reported average.**

# %%
sample = [69, 75, 79, 50, 57, 50, 57, 87, 73, 61, 71, 75, 77, 64, 54, 67, 76,
          74, 58, 66, 52, 58, 83, 57, 51, 86, 85, 81, 77, 54, 75, 61, 62, 64,
          81, 71, 75, 52, 73, 75, 67, 89, 53, 59, 83, 57, 70, 84, 57, 71, 60,
          81, 66, 63, 54, 61, 72, 60, 61, 71, 74, 79, 61, 65, 79, 83, 59, 66,
          85, 89, 74, 80, 56, 70, 58, 81, 84, 76, 89, 82, 72, 72, 87, 67, 85,
          73, 76, 65, 86, 64, 84, 56, 65, 76, 53, 84, 59, 89, 89, 56]

# %% [markdown]
# **H0 :** The average weight is 66 kg. <br>
# **H1 :** The average weight is more than 66 kg.

# %%
sample = np.array(sample)

# %%
pop_mean = 66
pop_std = 15

# Calculate sample statistics
# calculate sample size and sample mean
sample_size = len(sample)
sample_mean = sample.mean()
print('Sample Size : ', sample_size)
print('Sample Mean : ', sample_mean)
# Out:
# Sample Size :  100
# Sample Mean :  70.0

# %%
# Use sample data
# Convert the sample list into a NumPy array for numerical computations
# population parameters
sample = [69, 75, 79, 50, 57, 50, 57, 87, 73, 61, 71, 75, 77, 64, 54, 67, 76,
          74, 58, 66, 52, 58, 83, 57, 51, 86, 85, 81, 77, 54, 75, 61, 62, 64,
          81, 71, 75, 52, 73, 75, 67, 89, 53, 59, 83, 57, 70, 84, 57, 71, 60,
          81, 66, 63, 54, 61, 72, 60, 61, 71, 74, 79, 61, 65, 79, 83, 59, 66,
          85, 89, 74, 80, 56, 70, 58, 81, 84, 76, 89, 82, 72, 72, 87, 67, 85,
          73, 76, 65, 86, 64, 84, 56, 65, 76, 53, 84, 59, 89, 89, 56]
sample = np.array(sample)

pop_mean = 66
pop_std = 15

# Calculate sample statistics
# calculate sample size and sample mean
sample_size = len(sample)
sample_mean = sample.mean()

# Function to calculate the Z-score for the sample

def calculate_z_score(sample_mean, pop_mean, pop_std, sample_size):
  std_error = pop_std/sample_size ** 0.5
  z_score = (sample_mean - pop_mean)/std_error
  return z_score

# Compute the Z-score
z_value = calculate_z_score(sample_mean, pop_mean, pop_std, sample_size)

# Upper tailed test (right tailed test)
# Compute the p-value based on the Z-score
p_value = 1- norm.cdf(z_value)

# Conclusion
alpha = 0.05
if p_value < alpha:
    result = "We have sufficient evidence to reject the null hypothesis."
else:
    result = "We fail to reject the null hypothesis."

print(f"Z value: {z_value}\n"
      f"P value: {p_value}\n"
      f"Conclusion: {result}")
# Out:
# Z value: 2.6666666666666665
# P value: 0.003830380567589775
# Conclusion: We have sufficient evidence to reject the null hypothesis.

# %% [markdown]
# ---
# ---
# **2. A coach claims that the average team points per game for Chicago Bulls are 108 with a standard standard deviation of 15. You doubt that the average team points are less than 108 and take a sample of scores from 50 matches. Form the hypotheses and test the claim made by the coach.**

# %%
sample = [117,  99, 128,  81, 104, 102, 123,  90, 102, 128, 100, 110, 114,
          122, 115, 127,  88, 113,  90, 111,  95, 116,  90,  82,  98,  90,
          112, 123, 108, 120, 126, 120,  83, 121,  81,  98, 108,  84, 111,
          110, 102, 114, 121,  80, 104,  82,  83, 104, 112, 114]

# %% [markdown]
# **H0 :** The average points are 108. <br>
# **H1 :** The average points are less than 108.

# %%
sample = np.array(sample)

# %%
pop_mean = 108
pop_std = 15

# Calculate sample statistics
# calculate sample size and sample mean
sample_size = len(sample)
sample_mean = sample.mean()
print('Sample Size : ', sample_size)
print('Sample Mean : ', sample_mean)
# Out:
# Sample Size :  50
# Sample Mean :  105.12

# %%
# Use sample data
sample = [117,  99, 128,  81, 104, 102, 123,  90, 102, 128, 100, 110, 114,
          122, 115, 127,  88, 113,  90, 111,  95, 116,  90,  82,  98,  90,
          112, 123, 108, 120, 126, 120,  83, 121,  81,  98, 108,  84, 111,
          110, 102, 114, 121,  80, 104,  82,  83, 104, 112, 114]
# Convert the sample list into a NumPy array for numerical computations
sample = np.array(sample)
# population parameters
pop_mean = 108
pop_std = 15

# Calculate sample statistics
# calculate sample size and sample mean
sample_size = len(sample)
sample_mean = sample.mean()
# Function to calculate the Z-score for the sample
def calculate_z_score(sample_mean, pop_mean, pop_std, sample_size):
  std_error = pop_std/sample_size ** 0.5
  z_score = (sample_mean - pop_mean)/std_error
  return z_score

# Compute the Z-score
z_value = calculate_z_score(sample_mean, pop_mean, pop_std, sample_size)

# lower tailed test (left tailed test)
# calculating p value
p_value = norm.cdf(z_value)

# Conclusion
alpha = 0.05
if p_value < alpha:
    result = "We have sufficient evidence to reject the null hypothesis."
else:
    result = "We fail to reject the null hypothesis."

print(f"Z value: {z_value}\n"
      f"P value: {p_value}\n"
      f"Conclusion: {result}")
# Out:
# Z value: -1.3576450198781693
# P value: 0.08728817517809112
# Conclusion: We fail to reject the null hypothesis.

# %% [markdown]
# ---
# ---
# **3. A military aircraft manufacturing company after multiple trials claims that their new fighter aircraft has a minimum takeoff ditance of 800 meters with a standard deviation of 20 meters. The military decides to test the minimum takeoff distance and conducts 20 takeoff trials. Based on the data given below test whether the minimum takeoff distance is not more than 800 meters.**

# %%
sample = [784, 810, 801, 801, 806, 856, 800, 813, 802, 796, 771, 802, 799,
          852, 856, 788, 811, 785, 817, 795]

# %% [markdown]
# **H0 :** The average takeoff distance is 800. <br>
# **H1 :** The average takeoff distance is more than 800.

# %%
sample = np.array(sample)

# %%
pop_mean = 800
pop_std = 20

# Calculate sample statistics
# calculate sample size and sample mean
sample_size = len(sample)
sample_mean = sample.mean()
print('Sample Size : ', sample_size)
print('Sample Mean : ', sample_mean)
# Out:
# Sample Size :  20
# Sample Mean :  807.25

# %%
# Use sample data
sample = [784, 810, 801, 801, 806, 856, 800, 813, 802, 796, 771, 802, 799,
          852, 856, 788, 811, 785, 817, 795]
# Convert the sample list into a NumPy array for numerical computations
sample = np.array(sample)
# population parameters
pop_mean = 800
pop_std = 20

# Calculate sample statistics
# calculate sample size and sample mean
sample_size = len(sample)
sample_mean = sample.mean()

# Function to calculate the Z-score for the sample
def calculate_z_score(sample_mean, pop_mean, pop_std, sample_size):
  std_error = pop_std/sample_size ** 0.5
  z_score = (sample_mean - pop_mean)/std_error
  return z_score

# Calculate z score
z_value = calculate_z_score(sample_mean, pop_mean, pop_std, sample_size)

# upper tailed test
# calculating p value
p_value = 1- norm.cdf(z_value)

# Conclusion
alpha = 0.05
if p_value < alpha:
    result = "We have sufficient evidence to reject the null hypothesis."
else:
    result = "We fail to reject the null hypothesis."

print(f"Z value: {z_value}\n"
      f"P value: {p_value}\n"
      f"Conclusion: {result}")
# Out:
# Z value: 1.6211492836873473
# P value: 0.05249281327284039
# Conclusion: We fail to reject the null hypothesis.

# %% [markdown]
# ---
# ---
# **4. A Company claims that the average rating recieved by their product is 4.2 out of 5 with a standard deviation 0f 0.7. You doubt the claim and select ratings from 20 online reviews randomly. Based on the ratings given below verify whether the average ratings are less than the claim by the company.**

# %%
sample = [5,3,3,4,5,4,3,5,4,3,4,4.5,2,4,3,3,4,5,4,5]

# %% [markdown]
# **H0 :** The average rating is 4.2. <br>
# **H1 :** The average score is less than 4.2.

# %%
pop_mean = 4.2
pop_std = 0.7

# Write your code here
# sample size and sample mean
sample_size = len(sample)
sample_mean = np.mean(sample)
print('Sample Mean : ', sample_mean)
print('Sample Size : ', sample_size)
# Out:
# Sample Mean :  3.875
# Sample Size :  20

# %%
# Use sample data
sample = [5,3,3,4,5,4,3,5,4,3,4,4.5,2,4,3,3,4,5,4,5]
# Convert the sample list into a NumPy array for numerical computations
sample = np.array(sample)
# population parameters
pop_mean = 4.2
pop_std = 0.7

# Write your code here
# sample size and sample mean
sample_size = len(sample)
sample_mean = np.mean(sample)
# Function to calculate the Z-score for the sample
def calculate_z_score(sample_mean, pop_mean, pop_std, sample_size):
  std_error = pop_std/sample_size ** 0.5
  z_score = (sample_mean - pop_mean)/std_error
  return z_score

# Calculate z score
z_value = calculate_z_score(sample_mean, pop_mean, pop_std, sample_size)

# calculating p value for left-tailed test
p_value = norm.cdf(z_value)

# Conclusion
alpha = 0.05
if p_value < alpha:
    result = "We have sufficient evidence to reject the null hypothesis."
else:
    result = "We fail to reject the null hypothesis."

print(f"Z value: {z_value}\n"
      f"P value: {p_value}\n"
      f"Conclusion: {result}")
# Out:
# Z value: -2.076348836249806
# P value: 0.018930849801457632
# Conclusion: We have sufficient evidence to reject the null hypothesis.

# %% [markdown]
# ---
# ---
# **5. A salt producer uses a machine to fill the bags with salt and each bag has to be 1 kg each with a standard deviation of 0.003 kg. A randomly selected sample of 50 bags resulted in a mean of 1.01 kg.
# Perform the suitable test and verify if the machine needs to be recalibrated.**

# %% [markdown]
# **H0 :** The weight is 1kg. <br>
# **H1 :** The weight is not 1 kg.

# %%
pop_mean = 1
pop_std = 0.03

# sample size and sample mean
sample_size = 20
sample_mean = 1.01
print('Sample Mean : ', sample_mean)
print('Sample Size : ', sample_size)
# Out:
# Sample Mean :  1.01
# Sample Size :  20

# %%
# population parameters
pop_mean = 1
pop_std = 0.03

# sample size and sample mean
sample_size = 20
sample_mean = 1.01
# Function to calculate the Z-score for the sample

def calculate_z_score(sample_mean, pop_mean, pop_std, sample_size):
  std_error = pop_std/sample_size ** 0.5
  z_score = (sample_mean - pop_mean)/std_error
  return z_score
# Calculate z score
z_value = calculate_z_score(sample_mean, pop_mean, pop_std, sample_size)

# calculating p value
p_value = 1- norm.cdf(z_value)

# Conclusion
alpha = 0.05
if p_value < alpha/2:
    result = "We have sufficient evidence to reject the null hypothesis."
else:
    result = "We fail to reject the null hypothesis."

print(f"Z value: {z_value}\n"
      f"P value: {p_value}\n"
      f"Conclusion: {result}")
# Out:
# Z value: 1.4907119849998611
# P value: 0.06801856405707163
# Conclusion: We fail to reject the null hypothesis.

# %% [markdown]
# # End!
