# %% [markdown]
# <a href="https://colab.research.google.com/github/PavanPk1/MyPractice_Colab_notebooks/blob/main/Pandas_Practice_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instructions for Pandas Practice
# ---
# Welcome to the Pandas Practice! In this exercise, you will work with the Rick and Morty dataset to practice your data manipulation and analysis skills using Pandas. Please follow the instructions below carefully:
#
# 1. **Understand the Dataset**: The dataset used in this Practice is related to the Rick and Morty TV show. Familiarize yourself with the dataset's structure and content before starting.
#
# 2. **Read Each Question Thoroughly**: Each question in this Practice is designed to test different Pandas functionalities. Make sure you understand the requirements of each question before you begin coding.
#
# 3. **Write Your Code in the Provided Cells**: For each question, a code cell is provided where you should write your solution. Do not modify any other cells or sections of the notebook.
#
# 4. **Execute Your Code**: After writing your code in each cell, run the cell to check if your code produces the expected results. Verify that the output matches the requirements specified in the question.
#
# 5. **Complete All Questions**: Ensure that you attempt and complete all the questions provided in the notebook. Each question is designed to test different Pandas skills and concepts.
#
# 6. **Review Your Work**: Before submitting, double-check your answers and make sure all questions are addressed. Ensure that the notebook runs without errors and that all outputs are correct.
#
# 7. **Download Your Notebook**: Once you have completed all the questions and verified your solutions, download the notebook file (.ipynb). You can do this by selecting `File` > `Download` > `Download .ipynb` from the Google Colab menu.
#
# 8. **Submit Your Practice**: Upload the downloaded .ipynb file to the designated learning platform for submission.
#
# 9. **Verify Submission**: Ensure that you have uploaded the correct file and that it is not corrupted. If you encounter any issues with the file, you may need to resubmit.
#
# ---
#
# Good luck with your Practice!

# %%
import numpy as np
import pandas as pd

locations_data_url = "https://s3.ap-south-1.amazonaws.com/new-assets.ccbp.in/frontend/content/aiml/classical-ml/locations_dataset.csv"
episodes_data_url = "https://s3.ap-south-1.amazonaws.com/new-assets.ccbp.in/frontend/content/aiml/classical-ml/episodes_dataset.csv"
character_data_url = "https://s3.ap-south-1.amazonaws.com/new-assets.ccbp.in/frontend/content/aiml/classical-ml/characters_dataset.csv"

characters = pd.read_csv(character_data_url,index_col=0)
episodes = pd.read_csv(episodes_data_url,index_col=0)
locations = pd.read_csv(locations_data_url,index_col=0)

# %%
characters.head(1)
# Out:
#    id          name status species type gender  \
# 0   1  Rick Sanchez  Alive   Human  NaN   Male
#
#                                               origin  \
# 0  {'name': 'Earth (C-137)', 'url': 'https://rick...
#
#                                             location  \
# 0  {'name': 'Citadel of Ricks', 'url': 'https://r...
#
#                                                image  \
# 0  https://rickandmortyapi.com/api/character/avat...
#
#                                              episode  \
# 0  ['https://rickandmortyapi.com/api/episode/1', ...
#
#                                            url                   created
# 0  https://rickandmortyapi.com/api/character/1  2017-11-04T18:48:46.250Z

# %%
locations.head(1)
# Out:
#    id           name    type        dimension  \
# 0   1  Earth (C-137)  Planet  Dimension C-137
#
#                                            residents  \
# 0  ['https://rickandmortyapi.com/api/character/38...
#
#                                           url                   created
# 0  https://rickandmortyapi.com/api/location/1  2017-11-10T12:42:04.162Z

# %% [markdown]
# Q1. Find the locations with the longest name.

# %%
# write your code here
max_length = locations['name'].str.len().max()
longest_locations = locations.loc[locations['name'].str.len() == max_length, 'name'].iloc[0]

print(longest_locations)
# Out:
# Earth(ReplacementDimension)

# %% [markdown]
# Q2. Find the num of distribution of characters where the status is (unknown)?

# %%
# write your code here
status_distribution = characters[characters['status'] == 'unknown']['status'].value_counts()
status_distribution.name = 'count'
status_distribution.index.name = 'status'
print(status_distribution)
# Out:
# status
# unknown    6
# Name: count, dtype: int64

# %% [markdown]
# Q3. Find the episode with the earliest creation timestamp.

# %%
episodes.head(1)
# Out:
#     id                    name   air_date episode  \
# 19  20  LOOK WHO'S PURGING NOW 2015-09-27  S02E09
#
#                                            characters  \
# 19  ['https://rickandmortyapi.com/api/character/1'...
#
#                                            url                   created
# 19  https://rickandmortyapi.com/api/episode/20  2017-11-10T12:56:35.772Z

# %%
# write your code here
episodes['created'] = pd.to_datetime(episodes['created'])
earliest_date = episodes['created'].min()
earliest_episode = episodes.loc[episodes['created'] == earliest_date].iloc[0]

print(earliest_episode['name'])
# Out:
# PILOT

# %%
characters.head(1)
# Out:
#    id          name status species type gender  \
# 0   1  Rick Sanchez  Alive   Human  NaN   Male
#
#                                               origin  \
# 0  {'name': 'Earth (C-137)', 'url': 'https://rick...
#
#                                             location  \
# 0  {'name': 'Citadel of Ricks', 'url': 'https://r...
#
#                                                image  \
# 0  https://rickandmortyapi.com/api/character/avat...
#
#                                              episode  \
# 0  ['https://rickandmortyapi.com/api/episode/1', ...
#
#                                            url                   created
# 0  https://rickandmortyapi.com/api/character/1  2017-11-04T18:48:46.250Z

# %% [markdown]
# Q4. Count the number of characters for each species in the Characters DataFrame

# %%
# write your code here
species_count = characters['species'].value_counts()
species_count.name = 'count'
species_count.index.name = 'species'
print(species_count)
# Out:
# species
# Human    15
# Alien     5
# Name: count, dtype: int64

# %%
episodes.head(4)
# Out:
#    id                    name           air_date episode  \
# 0   1                   Pilot   December 2, 2013  S01E01
# 1   2           Lawnmower Dog   December 9, 2013  S01E02
# 2   3            Anatomy Park  December 16, 2013  S01E03
# 3   4  M. Night Shaym-Aliens!   January 13, 2014  S01E04
#
#                                           characters  \
# 0  ['https://rickandmortyapi.com/api/character/1'...
# 1  ['https://rickandmortyapi.com/api/character/1'...
# 2  ['https://rickandmortyapi.com/api/character/1'...
# 3  ['https://rickandmortyapi.com/api/character/1'...
#
#                                          url                   created
# 0  https://rickandmortyapi.com/api/episode/1  2017-11-10T12:56:33.798Z
# 1  https://rickandmortyapi.com/api/episode/2  2017-11-10T12:56:33.916Z
# 2  https://rickandmortyapi.com/api/episode/3  2017-11-10T12:56:34.022Z
# 3  https://rickandmortyapi.com/api/episode/4  2017-11-10T12:56:34.129Z

# %% [markdown]
# Q5. Group the Episodes DataFrame by `air_date` and print the total number of episodes across all seasons.

# %%
# write your code here
episodes_per_season = episodes.groupby('air_date').size()
print(episodes_per_season.count())
# Out:
# 20

# %% [markdown]
# Q.6 How many characters are there for each gender?

# %%
# write your code here
species_count = characters.groupby('gender')['id'].count()
print(species_count)
# Out:
# gender
# Female      4
# Male       15
# unknown     1
# Name: id, dtype: int64

# %% [markdown]
# Q.7 Apply a function to convert all episode titles in the Episodes DataFrame to uppercase.

# %%
episodes['name'] = episodes['name'].str.upper()
print(episodes[['name']])
# Out:
#                                        name
# 19                   LOOK WHO'S PURGING NOW
# 18  INTERDIMENSIONAL CABLE 2: TEMPTING FATE
# 17            BIG TROUBLE IN LITTLE SANCHEZ
# 8           SOMETHING RICKED THIS WAY COMES
# 7                             RIXTY MINUTES
# 6                       RAISING GAZORPAZORP
# 11                         A RICKLE IN TIME
# 5                            RICK POTION #9
# 4                      MEESEEKS AND DESTROY
# 3                    M. NIGHT SHAYM-ALIENS!
# 1                             LAWNMOWER DOG
# 0                                     PILOT
# 2                              ANATOMY PARK
# 13                 AUTO EROTIC ASSIMILATION
# 16                  THE RICKS MUST BE CRAZY
# 15                             GET SCHWIFTY
# 12                           MORTYNIGHT RUN
# 14                            TOTAL RICKALL
# 9      CLOSE RICK-COUNTERS OF THE RICK KIND
# 10                          RICKSY BUSINESS

# %% [markdown]
# Q.8 Filter the Characters DataFrame to show only characters with the species 'Human'.

# %%
# write your code here
humans = characters[characters['species'] == 'Human']
gender = characters[characters['gender'] == 'Male']['gender'].value_counts()
gender.name = 'count'
gender.index.name = 'gender'
print(gender)
# Out:
# gender
# Male    15
# Name: count, dtype: int64

# %% [markdown]
# Q.9 Find characters that contain the word 'Citadel' in their name.

# %%
# write your code here
citadel_characters = characters[characters['name'].str.contains('Citadel', case = False)]
print(citadel_characters)
# Out:
# Empty DataFrame
# Columns: [id, name, status, species, type, gender, origin, location, image, episode, url, created]
# Index: []

# %% [markdown]
# Q.10 Filter the episodes where aired year is 2013

# %%
episodes.head(1)
# Out:
#    id   name          air_date episode  \
# 0   1  PILOT  December 2, 2013  S01E01
#
#                                           characters  \
# 0  ['https://rickandmortyapi.com/api/character/1'...
#
#                                          url                   created
# 0  https://rickandmortyapi.com/api/episode/1  2017-11-10T12:56:33.798Z

# %%
# write your code here
episodes_2013 = episodes[pd.to_datetime(episodes['air_date']).dt.year == 2013]['name'].tolist()
print(episodes_2013)
# Out:
# ['PILOT', 'LAWNMOWER DOG', 'ANATOMY PARK']

# %%
characters.head(1)
# Out:
#    id          name status species type gender  \
# 0   1  Rick Sanchez  Alive   Human  NaN   Male
#
#                                               origin  \
# 0  {'name': 'Earth (C-137)', 'url': 'https://rick...
#
#                                             location  \
# 0  {'name': 'Citadel of Ricks', 'url': 'https://r...
#
#                                                image  \
# 0  https://rickandmortyapi.com/api/character/avat...
#
#                                              episode  \
# 0  ['https://rickandmortyapi.com/api/episode/1', ...
#
#                                            url                   created
# 0  https://rickandmortyapi.com/api/character/1  2017-11-04T18:48:46.250Z

# %%
episodes.head(1)
# Out:
#    id   name          air_date episode  \
# 0   1  PILOT  December 2, 2013  S01E01
#
#                                           characters  \
# 0  ['https://rickandmortyapi.com/api/character/1'...
#
#                                          url                   created
# 0  https://rickandmortyapi.com/api/episode/1  2017-11-10T12:56:33.798Z

# %% [markdown]
# Q.11 Get the top 3 characters with the most appearances in episodes

# %%
# write your code here
character_episodes_count = characters['episode'].apply(len).nlargest(3)
print(character_episodes_count)
# Out:
# 0    2337
# 1    2337
# 2    1928
# Name: episode, dtype: int64

# %% [markdown]
# Q.12 Find the total number of unique characters:

# %%
unique_characters = characters['origin'].apply(lambda x: eval(x)['name']).nunique()
print(unique_characters)
# Out:
# 4

# %% [markdown]
# Q. 13 Convert the Air Date column in the Episodes DataFrame to a DateTime format and find the most recent episode name.

# %%
episodes['air_date'] = pd.to_datetime(episodes['air_date'])

latest_date = episodes['air_date'].max()

most_recent_episode = episodes.loc[episodes['air_date'] == latest_date].iloc[0]

print(most_recent_episode['name'])
# Out:
# LOOK WHO'S PURGING NOW

# %% [markdown]
# Q. 14 Extract the most common character species

# %%
most_common_species = characters['species'].value_counts().index[0]

print(most_common_species)
# Out:
# Human

# %% [markdown]
# Q. 15  Find characters with a name starting with 'A'

# %%
# write your code here
name_count = characters[characters['name'].str.startswith('A')]
print(name_count['name'])
# Out:
# 5     Abadango Cluster Princess
# 6              Abradolf Lincler
# 7              Adjudicator Rick
# 8               Agency Director
# 9                    Alan Rails
# 10              Albert Einstein
# 11                    Alexander
# 12                 Alien Googah
# 13                  Alien Morty
# 14                   Alien Rick
# 15                 Amish Cyborg
# 16                        Annie
# 17                Antenna Morty
# 18                 Antenna Rick
# 19      Ants in my Eyes Johnson
# Name: name, dtype: object

# %% [markdown]
# # End!
