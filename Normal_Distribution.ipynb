# %% [markdown]
# <a href="https://colab.research.google.com/github/PavanPk1/MyPractice_Colab_notebooks/blob/main/Normal_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Normal Distribution Assignment

# %% [markdown]
# ## **Instructions for Normal Distribution Analysis Assignment**
#
# Welcome to the **Normal Distribution Analysis** assignment! In this assignment, you will analyze different real-world scenarios where data follows a **normal distribution**. You will calculate probabilities, quartiles, and specific threshold values, etc,.. using different libraries. Follow these instructions carefully to complete your assignment.

# %% [markdown]
# #### **1. Understand the Problem Statement**:
# You will be working with scenarios and there mean and std_dev:
# 1. **Employee Salaries**: Normally distributed with a **mean of 90,000** and a **standard deviation of 10,000**.
# 2. **Engineering Exam Scores**: Normally distributed with a **mean of 500** and a **standard deviation of 120**.
# 3. **City Population Age Distribution**: Normally distributed with a **mean age of 35 years** and a **standard deviation of 10 years**.
#
# Your task is to compute probabilities, quartiles, and specific threshold values, etc,.. using **normal distribution functions**.
#
#
# #### **2. Read Each Question Carefully**:
# Each question is designed to test your understanding of **normal distribution calculations**, including:
# - **Probability calculations** (e.g., P(X < a), P(X > b), P(a ≤ X ≤ b))
# - **Percentile and quartile calculations** (e.g., Q1, Q2, Q3)
# - **Finding threshold values** for specific percentiles.
#
# Make sure you understand what is required before writing your code.
#
#
# #### **3. Write Your Code in the Provided Cells**:
# - A **code cell** is provided for each question. Write your Python code in the designated cell.
# - Ensure you use appropriate **SciPy functions** for probability calculations and percentile calculations.
#
#
# #### **4. Run Your Code**:
# - After writing your code, **run the cell** to check if your calculations are correct.
# - Verify that your output matches expected probability values.
#
#
# #### **5. Debug if Necessary**:
# If your results are incorrect:
#    - Review your code for logical errors.
#    - Use additional print statements or temporary code cells for debugging.
#    - Ensure correct usage of **normal distribution functions**.
#
#
# #### **6. Complete All Questions**:
# - Answer **all the questions** related to **employee salaries, exam scores, and population age distribution**.
# - Each question tests a different aspect of normal distribution and statistical probability.
#
#
# #### **7. Review Your Work**:
# Before submission, check that:
#    - All calculations are **correct and properly formatted**.
#    - The results are **clear and meaningful**.
#    - Your code runs without errors.
#
#
# #### **8. Download Your Notebook**:
# - Once completed, **download your notebook file (`.ipynb`)** by navigating to:
#   **File > Download > Download `.ipynb`**.
#
#
# #### **9. Submit Your Assignment**:
# - Upload the **downloaded `.ipynb` file** to the designated learning platform.
#
#
# #### **10. Verify Submission**:
# Double-check your submission to ensure:
#    - The uploaded file is correct.
#    - There are no **missing answers or errors**.
#    - If any issues arise, re-upload the correct file.
#
# ---
#
# **Good luck with your Normal Distribution Analysis! 🚀**

# %%
# Run this code cell
import numpy as np
import pandas as pd
from scipy.stats import norm
import scipy.stats as stats

def z_score(x, mean, std):
    return (x - mean) / std

# %% [markdown]
# ---
# ---
# **1. The salaries of employees in an organization are normally distributed with mean 90000 and standard deviation 10000.**

# %%
mean_salary = 90000    # mean salary
std_salary  = 10000    # standard deviation of salary

# %% [markdown]
# **1.a.** What is the probability of an employee having salary less than 75000?

# %%
# Write your code here
# P(x < 75000)
mean_salary = 90000    # mean salary
std_salary  = 10000    # standard deviation of salary
prob_less_75000 = norm.cdf(75000, mean_salary, std_salary)
print(prob_less_75000)
# Out:
# 0.06680720126885807

# %% [markdown]
# **1.b.** What is the probability of an employee having salary more than 100000?

# %%
# Write your code here
# P(x > 100000) = 1 - P(x <= 100000)
mean_salary = 90000    # mean salary
std_salary  = 10000    # standard deviation of salary
prob_more_100000 = 1 - norm.cdf(100000, mean_salary, std_salary)
print(prob_more_100000)
# Out:
# 0.15865525393145707

# %% [markdown]
# **1.c.** What is the probabilty of an employee salary between 80000 to 120000

# %%
# Write your code here
# P(80000 <= x <= 120000) = P(x <= 120000) - P(x <= 80000)
mean_salary = 90000    # mean salary
std_salary  = 10000    # standard deviation of salary
prob_between_80000_120000 = norm.cdf(120000, mean_salary, std_salary) - norm.cdf(80000, mean_salary, std_salary)
print(prob_between_80000_120000)
# Out:
# 0.8399948480369128

# %% [markdown]
# ---
# ---
# **2. The scores(out of 1000) for an engineering entrance exam are normally distributed with a mean score of 500 and a standard deviation of 120.**

# %%
mean_exam = 500      # mean of exma scores
std_exam  = 120      # Standard deviation of exam scores

# %% [markdown]
# **1.a.** What is the probability of a candidate scoring less than 600?

# %%
# Write your code here
mean_exam = 500      # mean of exma scores
std_exam  = 120      # Standard deviation of exam scores
prob_less_600 = norm.cdf(600,mean_exam,std_exam)
print(prob_less_600)
# Out:
# 0.7976716190363569

# %% [markdown]
# **1.b.** What is the probability of a candidate scoring more than 700?

# %%
# Write your code here
mean_exam = 500      # mean of exma scores
std_exam  = 120      # Standard deviation of exam scores
prob_more_700 = 1 - norm.cdf(700,mean_exam,std_exam)
print(prob_more_700)
# Out:
# 0.047790352272814696

# %% [markdown]
# **1.c.** What is the probability of a candidate scoring between 450 to 650?

# %%
# Write your code here
mean_exam = 500      # mean of exma scores
std_exam  = 120      # Standard deviation of exam scores
prob_between_450_650 = norm.cdf(650,mean_exam,std_exam) - norm.cdf(450,mean_exam,std_exam)
print(prob_between_450_650)
# Out:
# 0.5559

# %% [markdown]
# **1.d.** Candidates falling in the bottom 35% will be considered as failing the test. How much a candidate has to score to pass?q

# %%
# Write your code here
mean_exam = 500      # mean of exma scores
std_exam  = 120      # Standard deviation of exam scores
passing_score = norm.ppf(0.35, mean_exam, std_exam)

# Display result
print(passing_score)
# Out:
# 453.7615440310919

# %% [markdown]
# **1.e.** The best engineering college only accepts top 0.1% of candidates. How much a candidate has to score to be in that college?

# %%
# Write your code here
# let that score be x
# Probability of scoring above x = 0.001
mean_exam = 500      # mean of exma scores
std_exam  = 120      # Standard deviation of exam scores
top_college_score = norm.ppf(0.999, mean_exam, std_exam)

# Display result
print(top_college_score)
# Out:
# 870.8278767401375

# %% [markdown]
# ---
# ---
# **3. The mean age of population in a city is 35 with a standard deviation of 10. Assuming the age is normaly distributed answer the following questions.**

# %%
mean_age = 35
std_age = 10

# %% [markdown]
# **1.a.** What percentage of residents have age below 50?

# %%
# Write your code here
mean_age = 35
std_age = 10
p_below_50 = norm.cdf(50, mean_age, std_age)
print(p_below_50*100)
# Out:
# 93.3192798731142

# %% [markdown]
# **1.b.** What percentage of residents have age above 30?

# %%
# Write your code here
mean_age = 35
std_age = 10
p_above_30 = 1 - norm.cdf(30, mean_age, std_age)
print(p_above_30*100)
# Out:
# 69.14624612740131

# %% [markdown]
# **1.c.** What age corresponds to the second quartile?

# %%
# Second quartile : The value below which 50 percent of residents are aged
# Or the age above which 50 percent of rersidents are aged
mean_age = 35
std_age = 10
second_quartile = norm.ppf(0.5, mean_age, std_age)
print(second_quartile)
# Out:
# 35.0

# %% [markdown]
# ppf stands for Percent Point Function (also called the quantile function or inverse CDF). It does the opposite of the CDF.
#
# CDF: give a value
# x
# x → returns probability
# P
# (
# X
# ≤
# x
# )
# P(X≤x).
#
# PPF: give a probability
# p
# p → returns the value
# x
# x such that
# P
# (
# X
# ≤
# x
# )
# =
# p
# P(X≤x)=p.
#
# For quartiles you know the probability (e.g. 0.25, 0.5, 0.75) and you want the value of the variable at that percentile.

# %% [markdown]
# **1.d.** What age values make up the inter quartile range?

# %%
# first quartile : the value below which 25% of residents are aged
# or the value above which 75% of residents are aged
mean_age = 35
std_age = 10
first_quartile = norm.ppf(0.25, mean_age, std_age)
third_quartile = norm.ppf(0.75, mean_age, std_age)

# Expected output
# (28.255102498039182, 41.744897501960814)
print(f"({first_quartile}, {third_quartile})")
# Out:
# (28.255102498039182, 41.744897501960814)

# %% [markdown]
# ## End
