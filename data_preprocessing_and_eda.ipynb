# %% [markdown]
# <a href="https://colab.research.google.com/github/PavanPk1/MyPractice_Colab_notebooks/blob/main/data_preprocessing_and_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import Data and Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import style
style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ![Screenshot 2025-11-09 at 08.23.02.png](data:image/png;base64,...)

# %%
titanic = pd.read_csv('train_dataset.csv')
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### we can now see there are null values in age,cabin,embarked as the total size is not matched with the shape

# %%
titanic.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
print('Survived : ', titanic.Survived.unique())
print('Pclasses : ', titanic.Pclass.unique())
print('Gender   : ', titanic.Sex.unique())
print('Embarked : ', titanic.Embarked.dropna().unique())
# Out:
# Survived :  [0 1]
# Pclasses :  [3 1 2]
# Gender   :  ['male' 'female']
# Embarked :  ['S' 'C' 'Q']

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Check for duplicates

# %% [markdown]
# ![Screenshot 2025-11-09 at 08.29.21.png](data:image/png;base64,...)

# %%
titanic.duplicated().sum()
# Out:
# np.int64(0)

# %%
titanic.drop_duplicates(inplace = True)  # To remove duplicates

# %% [markdown]
# ### Dealing with missing values

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# - **If number of missing values in a column is very large wrt total values then dropping that column is a suitable strategy**

# %%
687/891
# Out:
# 0.7710437710437711

# %%
titanic.drop('Cabin', axis = 1, inplace = True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
# - **In numerical columns missing values can be replaced by the mean or median of that column**

# %%
plt.figure(figsize = (12,5), dpi = 200)
sns.distplot(titanic.Age, hist = False)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
print(f"mean for the age column: {titanic.Age.mean()}")
print(f"median for the age column: {titanic.Age.median()}")

# not much right schewd data so we might can go with the mean
# Out:
# mean for the age column: 29.69911764705882
# median for the age column: 28.0

# %%
mean_age = titanic.Age.mean()
titanic.Age.replace(np.nan, mean_age, inplace = True)

# %%
titanic.Age.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - **In categorical columns missing values can be replaced with mode**

# %%
mode_emb = titanic.Embarked.dropna().mode()[0]
mode_emb
# Out:
# 'S'

# %%
mode_emb = titanic.Embarked.dropna().mode()[0]
titanic.Embarked.replace(np.nan, mode_emb, inplace = True)

# %%
titanic.Embarked.isnull().sum()
# Out:
# np.int64(0)

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## Strategies to deal with missing values
# - If number of missing values in a column is very large wrt total values then dropping that column is a suitable strategy
# - In numerical columns missing values can be replaced by the mean or median of that column
# - In categorical columns missing values cam be replaced with mode
# - If number of rows having missing values is very small wrt total rows then these rows can be dropped
#                           - titanic.dropna(inplace = True)

# %% [markdown]
#     - titanic.dropna(inplace=True).  # helps us to drop the rows

# %%
import pandas as pd
df = pd.DataFrame({'A': [1, None, 3], 'B': [4, 5, None]})
df_cleaned = df.dropna()
print(df.dropna(inplace=True))
# Out:
# None

# %%
import pandas as pd
import numpy as np

# Sample DataFrame with some missing values
df = pd.DataFrame({
    'A': [1, np.nan, 3, 4],
    'B': [5, 6, np.nan, np.nan],
    'C': [7, 8, 9, np.nan]
})

# The thresh parameter in dropna() specifies the minimum number of non-NaN values
  # required in a row (or column) to keep that row (or column). If a row has at least thresh
      # non-null values, it is retained; otherwise, it is dropped.​
# For example:
# If you set thresh=2, rows with 2 or more non-null values are kept.
# Rows with fewer than 2 non-null values are removed.
cleaned_df = df.dropna(thresh=2)

print(cleaned_df)
# Out:
#      A    B    C
# 0  1.0  5.0  7.0
# 1  NaN  6.0  8.0
# 2  3.0  NaN  9.0

# %% [markdown]
# ----
# ----

# %%
# Creating a new column family_members by adding SibSp and Parch
titanic['family_members'] = titanic.SibSp + titanic.Parch
titanic.drop(['SibSp', 'Parch'], inplace = True, axis = 1)

titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Embarked  family_members
# 0         A/5 21171   7.2500        S               1
# 1          PC 17599  71.2833        C               1
# 2  STON/O2. 3101282   7.9250        S               0
# 3            113803  53.1000        S               1
# 4            373450   8.0500        S               0

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# How many passengers survived and how many did not survive
plt.figure(figsize = (12,5), dpi = 200)
sns.countplot(x = 'Survived', data = titanic)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
titanic.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
survival_ratio = titanic.Survived.value_counts(normalize = True)
print(survival_ratio)
print('Percentage of survivors : ', round(survival_ratio[1]*100,2))
print('Percentage of dead      : ', round(survival_ratio[0]*100,2))
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64
# Percentage of survivors :  38.38
# Percentage of dead      :  61.62

# %%
temp = titanic.groupby('Sex')['Survived']
print(temp.value_counts())
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
# Analysing gender and survival
plt.figure(figsize = (12,5), dpi = 200)
sns.countplot(x = 'Sex', hue = 'Survived', data = titanic)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
svl_rate = titanic.groupby('Sex').Survived.value_counts(normalize = True)
svl_rate
# Out:
# Sex     Survived
# female  1           0.742038
#         0           0.257962
# male    0           0.811092
#         1           0.188908
# Name: proportion, dtype: float64

# %%
print('Percentage of female survivors : ', round(svl_rate['female'][1]*100,2))
print('Percentage of dead females     : ', round(svl_rate['female'][0]*100,2))
print('Percentage of male survivors   : ', round(svl_rate['male'][1]*100,2))
print('Percentage of dead males       : ', round(svl_rate['male'][0]*100,2))
# Out:
# Percentage of female survivors :  74.2
# Percentage of dead females     :  25.8
# Percentage of male survivors   :  18.89
# Percentage of dead males       :  81.11

# %%
svl_rate['male']
# Out:
# Survived
# 0    0.811092
# 1    0.188908
# Name: proportion, dtype: float64

# %%
svl_rate = svl_rate.sort_index()
males = svl_rate['male']
females = svl_rate['female']
labels = ['Dead', 'Survived']

plt.figure(figsize = (18,5), dpi = 200, facecolor = '#d0e1f2')
plt.subplot(1,2,1)
plt.pie(males, autopct = '%1.1f%%', labels = labels, explode = [0, 0.1])
plt.title('Male Survival')
plt.subplot(1,2,2)
plt.pie(females, autopct = '%1.1f%%', labels = labels, explode = [0, 0.1])
plt.title('Female Survival')
# Out:
# Text(0.5, 1.0, 'Female Survival')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Embarked  family_members
# 0         A/5 21171   7.2500        S               1
# 1          PC 17599  71.2833        C               1
# 2  STON/O2. 3101282   7.9250        S               0
# 3            113803  53.1000        S               1
# 4            373450   8.0500        S               0

# %%
# Analysing passenger class and survival
plt.figure(figsize = (12,5), dpi = 200)
sns.countplot(x = 'Pclass', hue = 'Survived', data = titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
titanic.groupby('Pclass')['Survived'].value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %%
svl_rate = titanic.groupby('Pclass')['Survived'].value_counts(normalize  = True)
svl_rate
# Out:
# Pclass  Survived
# 1       1           0.629630
#         0           0.370370
# 2       0           0.527174
#         1           0.472826
# 3       0           0.757637
#         1           0.242363
# Name: proportion, dtype: float64

# %%
print('Percentage of 1st Passenger class Survivors : ', round(svl_rate[1][1]*100,2), '%')
print('Percentage of 1st Passenger class Dead      : ', round(svl_rate[1][0]*100,2), '%')
print('Percentage of 2nd Passenger class Survivors : ', round(svl_rate[2][1]*100,2), '%')
print('Percentage of 2nd Passenger class Dead      : ', round(svl_rate[2][0]*100,2), '%')
print('Percentage of 3rd Passenger class Survivors : ', round(svl_rate[3][1]*100,2), '%')
print('Percentage of 3rd Passenger class Dead      : ', round(svl_rate[3][0]*100,2), '%')
# Out:
# Percentage of 1st Passenger class Survivors :  62.96 %
# Percentage of 1st Passenger class Dead      :  37.04 %
# Percentage of 2nd Passenger class Survivors :  47.28 %
# Percentage of 2nd Passenger class Dead      :  52.72 %
# Percentage of 3rd Passenger class Survivors :  24.24 %
# Percentage of 3rd Passenger class Dead      :  75.76 %

# %%
svl_rate = svl_rate.sort_index()
pclass1, pclass2, pclass3 = svl_rate[1], svl_rate[2], svl_rate[3]
labels = ['Dead', 'Survived']

plt.figure(figsize = (18,6), dpi = 200, facecolor = '#d0e1f2')
plt.subplot(1,3,1)
plt.pie(pclass1, autopct = '%1.1f%%', labels = labels, explode = [0, 0.1])
plt.title('Passenger Class1')
plt.subplot(1,3,2)
plt.pie(pclass2, autopct = '%1.1f%%', labels = labels, explode = [0, 0.1])
plt.title('Passenger Class2')
plt.subplot(1,3,3)
plt.pie(pclass3, autopct = '%1.1f%%', labels = labels, explode = [0, 0.1])
plt.title('Passenger Class3')
# Out:
# Text(0.5, 1.0, 'Passenger Class3')

# %%
# Analysing Embarked and survival
plt.figure(figsize = (12,5), dpi = 200)
sns.countplot(x = 'Embarked', hue = 'Survived', data = titanic)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
svl_rate = titanic.groupby('Embarked')['Survived'].value_counts(normalize  = True)
svl_rate
# Out:
# Embarked  Survived
# C         1           0.553571
#           0           0.446429
# Q         0           0.610390
#           1           0.389610
# S         0           0.660991
#           1           0.339009
# Name: proportion, dtype: float64

# %%
# Fare and Passenger class
plt.figure(figsize = (12,5), dpi = 200)
sns.barplot(x = 'Pclass', y = 'Fare', data = titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
plt.figure(figsize = (16,5), dpi = 200)
sns.boxplot(x = 'Pclass', y = 'Fare', data = titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
# Fare and Survived
plt.figure(figsize = (16,5), dpi = 200)
plt.subplot(1,2,1)
sns.barplot(x = 'Survived', y = 'Fare', data = titanic)
plt.subplot(1,2,2)
sns.boxplot(x = 'Survived', y = 'Fare', data = titanic)
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
titanic[titanic.Fare > 500]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age    Ticket      Fare Embarked  family_members
# 258  female  35.0  PC 17755  512.3292        C               0
# 679    male  36.0  PC 17755  512.3292        C               1
# 737    male  35.0  PC 17755  512.3292        C               0

# %%
# Age
plt.figure(figsize = (16,5), dpi = 200)
plt.subplot(1,2,1)
sns.violinplot(y = 'Age', data = titanic)
plt.subplot(1,2,2)
sns.boxplot(y = 'Age', data = titanic)
# Out:
# <Axes: ylabel='Age'>

# %%
# Age and Survived
plt.figure(figsize = (16,5), dpi = 200)
plt.subplot(1,2,1)
sns.barplot(x = 'Survived', y = 'Age', data = titanic)
plt.subplot(1,2,2)
sns.boxplot(x = 'Survived', y = 'Age', data = titanic)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
# Family members and survived
plt.figure(figsize = (16,8), dpi = 200)
sns.countplot(x = 'family_members', hue = 'Survived', data = titanic)
# Out:
# <Axes: xlabel='family_members', ylabel='count'>
