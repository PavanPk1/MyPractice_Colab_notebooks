# %% [markdown]
# # Sales Prediction (Decision Tree Regression)

# %% [markdown]
# ### Problem Statement
#
# Build a model which predicts sales (thosands of units) based on the money spent (in thousands of dollers) on different platforms for marketing.

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Data

# %%
advertising = pd.read_csv("Advertising.csv",index_col=0)
advertising.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# ## Data Inspection

# %%
advertising.shape
# Out:
# (200, 4)

# %%
advertising.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
advertising.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ## Data Cleaning

# %%
advertising.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# ## Outlier Analysis

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,3,1)
plt1 = sns.boxplot(advertising['TV'])

plt.subplot(1,3,2)
plt2 = sns.boxplot(advertising['Newspaper'])

plt.subplot(1,3,3)
plt3 = sns.boxplot(advertising['Radio'])

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.boxplot(advertising['Sales'])
plt.show()

# %%
# Let's see how Sales are related with other variables using scatter plot.
sns.pairplot(advertising, x_vars=['TV', 'Newspaper', 'Radio'], y_vars='Sales', height=4, aspect=1, kind='scatter')
plt.show()

# %%
# Let's see the correlation between different variables.
sns.heatmap(advertising.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# ## Model Building

# %%
X = advertising.drop('Sales', axis=1)
y = advertising['Sales']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.2, random_state = 42)

# %%
# Let's now take a look at the train dataset
X_train.head()
# Out:
#         TV  Radio  Newspaper
# 176  276.9   48.9       41.8
# 135   36.9   38.6       65.6
# 168  206.8    5.2       19.4
# 184  287.6   43.0       71.8
# 64   102.7   29.6        8.4

# %%
y_train.head()
# Out:
# 176    27.0
# 135    10.8
# 168    12.2
# 184    26.2
# 64     14.0
# Name: Sales, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': 42,
#  'splitter': 'best'}

# %%
# Predict on the test set
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 5.178

# %%
# Visualize actual vs predicted values
plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual')
plt.scatter(range(len(y_pred)), y_pred, color='red', label='Predicted')
plt.title('Actual vs Predicted Prices')
plt.xlabel('Test Data Index')
plt.ylabel('Price ($)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_search = GridSearchCV(DecisionTreeRegressor(random_state=42),
                           param_grid,
                           cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42),
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
print("Best Parameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
# Predict on the test set
y_pred = best_model.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 5.178

# %%
# Visualize actual vs predicted values
plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual')
plt.scatter(range(len(y_pred)), y_pred, color='red', label='Predicted')

plt.title('Actual vs Predicted Prices')
plt.xlabel('Test Data Index')
plt.ylabel('Price ($)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Random Search CV

# %%
from scipy.stats import randint
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    'max_depth': randint(3, 15),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 20),
    'max_leaf_nodes': randint(10, 100)
}

# %%
# initialize random search
random_search = RandomizedSearchCV(estimator=DecisionTreeRegressor(random_state=42),
                                   param_distributions=param_dist,
                                   n_iter=100,  #number of iterations
                                   cv=5,
                                   scoring='neg_mean_squared_error',
                                   n_jobs=-1,
                                   verbose=2
                                  )

# Fit Random Search to the training data
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x13e55ad10>,
#                                         'max_leaf_nodes': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x13e558950>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x13e559810>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x13e508690>},
#                    scoring='neg_mean_squared_error', verbose=2)

# %%
print("Best Parameters:", random_search.best_params_)
best_model = random_search.best_estimator_
# Out:
# Best Parameters: {'max_depth': 8, 'max_leaf_nodes': 51, 'min_samples_leaf': 4, 'min_samples_split': 4}

# %%
# Predict on the test set
y_pred = best_model.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 8.761743640518707

# %%
# Visualize actual vs predicted values
plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual')
plt.scatter(range(len(y_pred)), y_pred, color='red', label='Predicted')

plt.title('Actual vs Predicted Prices')
plt.xlabel('Test Data Index')
plt.ylabel('Price ($)')
plt.legend()
plt.grid()
plt.show()
# Out:
# [CV] END max_depth=14, max_leaf_nodes=28, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=51, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=51, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=30, min_samples_leaf=1, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=36, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=95, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=95, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=12, min_samples_leaf=3, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=33, min_samples_leaf=17, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=33, min_samples_leaf=17, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=60, min_samples_leaf=4, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=60, min_samples_leaf=4, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=47, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=47, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=60, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=60, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=58, min_samples_leaf=7, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=58, min_samples_leaf=7, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=41, min_samples_leaf=7, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=41, min_samples_leaf=7, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=13, min_samples_leaf=15, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=35, min_samples_leaf=13, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=18, min_samples_leaf=13, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=18, min_samples_leaf=13, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=39, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=39, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=34, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=34, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=34, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=34, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=30, min_samples_leaf=19, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=53, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=53, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_leaf=10, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=98, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=98, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=98, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=60, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=60, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=60, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=60, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=34, min_samples_leaf=8, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=34, min_samples_leaf=8, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=34, min_samples_leaf=8, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=34, min_samples_leaf=8, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=53, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=53, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=53, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=53, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=53, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=69, min_samples_leaf=9, min_samples_split=19; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=69, min_samples_leaf=9, min_samples_split=19; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=69, min_samples_leaf=9, min_samples_split=19; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=86, min_samples_leaf=18, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=69, min_samples_leaf=9, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=69, min_samples_leaf=9, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=69, min_samples_leaf=9, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=69, min_samples_leaf=9, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=69, min_samples_leaf=9, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=34, min_samples_leaf=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=34, min_samples_leaf=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=77, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=77, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=77, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=77, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=87, min_samples_leaf=4, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=87, min_samples_leaf=4, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=87, min_samples_leaf=4, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=87, min_samples_leaf=4, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=87, min_samples_leaf=4, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=92, min_samples_leaf=16, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=92, min_samples_leaf=16, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=92, min_samples_leaf=16, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=92, min_samples_leaf=16, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=92, min_samples_leaf=16, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=53, min_samples_leaf=4, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=53, min_samples_leaf=4, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=28, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=52, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=51, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=51, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=30, min_samples_leaf=1, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=30, min_samples_leaf=1, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=36, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=95, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=95, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=12, min_samples_leaf=3, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=12, min_samples_leaf=3, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=33, min_samples_leaf=17, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=33, min_samples_leaf=17, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=60, min_samples_leaf=4, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=47, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=60, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=60, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=22, min_samples_leaf=6, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=58, min_samples_leaf=7, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=87, min_samples_leaf=12, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=87, min_samples_leaf=12, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=13, min_samples_leaf=15, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=13, min_samples_leaf=15, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=57, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=18, min_samples_leaf=13, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=18, min_samples_leaf=13, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=18, min_samples_leaf=13, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=78, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=47, min_samples_leaf=16, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=47, min_samples_leaf=16, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=47, min_samples_leaf=16, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=69, min_samples_leaf=9, min_samples_split=19; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=69, min_samples_leaf=9, min_samples_split=19; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=41, min_samples_leaf=8, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=41, min_samples_leaf=8, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=41, min_samples_leaf=8, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=41, min_samples_leaf=8, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=41, min_samples_leaf=8, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=33, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=34, min_samples_leaf=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=34, min_samples_leaf=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=34, min_samples_leaf=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=78, min_samples_leaf=16, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=78, min_samples_leaf=16, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=78, min_samples_leaf=16, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=78, min_samples_leaf=16, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=78, min_samples_leaf=16, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=53, min_samples_leaf=4, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=53, min_samples_leaf=4, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=53, min_samples_leaf=4, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=72, min_samples_leaf=1, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=72, min_samples_leaf=1, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=72, min_samples_leaf=1, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=72, min_samples_leaf=1, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=72, min_samples_leaf=1, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=35, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=35, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=35, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=35, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=35, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=45, min_samples_leaf=19, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=45, min_samples_leaf=19, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=45, min_samples_leaf=19, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=28, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=42, min_samples_leaf=8, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=42, min_samples_leaf=8, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=41, min_samples_leaf=7, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=41, min_samples_leaf=7, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=35, min_samples_leaf=13, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=35, min_samples_leaf=13, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=12, min_samples_leaf=11, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=12, min_samples_leaf=11, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=12, min_samples_leaf=11, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=12, min_samples_leaf=11, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=14, min_samples_leaf=18, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=14, min_samples_leaf=18, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=90, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=90, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=94, min_samples_leaf=18, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=94, min_samples_leaf=18, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=61, min_samples_leaf=10, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=61, min_samples_leaf=10, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=61, min_samples_leaf=10, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=61, min_samples_leaf=10, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=61, min_samples_leaf=10, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=31, min_samples_leaf=16, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=47, min_samples_leaf=10, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=47, min_samples_leaf=10, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=47, min_samples_leaf=10, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=47, min_samples_leaf=10, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=47, min_samples_leaf=10, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=79, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=79, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=79, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=18, min_samples_leaf=5, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=93, min_samples_leaf=15, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=93, min_samples_leaf=15, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=93, min_samples_leaf=15, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=93, min_samples_leaf=15, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=93, min_samples_leaf=15, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=44, min_samples_leaf=19, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=44, min_samples_leaf=19, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=89, min_samples_leaf=12, min_samples_split=19; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=89, min_samples_leaf=12, min_samples_split=19; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=89, min_samples_leaf=12, min_samples_split=19; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=89, min_samples_leaf=12, min_samples_split=19; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=35, min_samples_leaf=11, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=35, min_samples_leaf=11, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=35, min_samples_leaf=11, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=35, min_samples_leaf=11, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=35, min_samples_leaf=11, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=18, min_samples_leaf=19, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=18, min_samples_leaf=19, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=18, min_samples_leaf=19, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=18, min_samples_leaf=19, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=18, min_samples_leaf=19, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=50, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=50, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=30, min_samples_leaf=19, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_leaf=10, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_leaf=10, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_leaf=10, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_leaf=10, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=94, min_samples_leaf=17, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=14, min_samples_leaf=18, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=14, min_samples_leaf=18, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=14, min_samples_leaf=18, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=32, min_samples_leaf=16, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=32, min_samples_leaf=16, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=32, min_samples_leaf=16, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=32, min_samples_leaf=16, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=32, min_samples_leaf=16, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=94, min_samples_leaf=18, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=94, min_samples_leaf=18, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=94, min_samples_leaf=18, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=99, min_samples_leaf=19, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=63, min_samples_leaf=3, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=63, min_samples_leaf=3, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=63, min_samples_leaf=3, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=63, min_samples_leaf=3, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=63, min_samples_leaf=3, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=26, min_samples_leaf=18, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=26, min_samples_leaf=18, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=45, min_samples_leaf=19, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=45, min_samples_leaf=19, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=85, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=85, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=85, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=85, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=85, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=76, min_samples_leaf=2, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=76, min_samples_leaf=2, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=76, min_samples_leaf=2, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=76, min_samples_leaf=2, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=76, min_samples_leaf=2, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=53, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=53, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=53, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=53, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=30, min_samples_leaf=19, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=79, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=79, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=60, min_samples_leaf=15, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=60, min_samples_leaf=15, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=60, min_samples_leaf=15, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=60, min_samples_leaf=15, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=60, min_samples_leaf=15, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=96, min_samples_leaf=13, min_samples_split=13; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=52, min_samples_leaf=13, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=52, min_samples_leaf=13, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=52, min_samples_leaf=13, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=52, min_samples_leaf=13, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=18, min_samples_leaf=5, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=18, min_samples_leaf=5, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=18, min_samples_leaf=5, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=18, min_samples_leaf=5, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=50, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=50, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=50, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=67, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=67, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=67, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=67, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=67, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=28, min_samples_leaf=10, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=28, min_samples_leaf=10, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=28, min_samples_leaf=10, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=28, min_samples_leaf=10, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=28, min_samples_leaf=10, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=58, min_samples_leaf=16, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=58, min_samples_leaf=16, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=58, min_samples_leaf=16, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=30, min_samples_leaf=19, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=42, min_samples_leaf=8, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=42, min_samples_leaf=8, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=53, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=41, min_samples_leaf=7, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=19, min_samples_leaf=17, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=19, min_samples_leaf=17, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=19, min_samples_leaf=17, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=12, min_samples_leaf=11, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=39, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=39, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=39, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=60, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_leaf=6, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_leaf=6, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_leaf=6, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=34, min_samples_leaf=8, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=95, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=95, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=95, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=53, min_samples_leaf=17, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=53, min_samples_leaf=17, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=53, min_samples_leaf=17, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=53, min_samples_leaf=17, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=53, min_samples_leaf=17, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=16, min_samples_leaf=11, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=16, min_samples_leaf=11, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=16, min_samples_leaf=11, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=16, min_samples_leaf=11, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=16, min_samples_leaf=11, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=24, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=24, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=24, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=53, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=26, min_samples_leaf=14, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=26, min_samples_leaf=14, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=26, min_samples_leaf=14, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=26, min_samples_leaf=14, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=26, min_samples_leaf=14, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=81, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=81, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=81, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=81, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=81, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=96, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=96, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=96, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=96, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=96, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=28, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=33, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=33, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=33, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=33, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=99, min_samples_leaf=19, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=99, min_samples_leaf=19, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=99, min_samples_leaf=19, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=99, min_samples_leaf=19, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=24, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=24, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=81, min_samples_leaf=3, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=81, min_samples_leaf=3, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=81, min_samples_leaf=3, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=81, min_samples_leaf=3, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=81, min_samples_leaf=3, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=52, min_samples_leaf=13, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=76, min_samples_leaf=9, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=76, min_samples_leaf=9, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=76, min_samples_leaf=9, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=76, min_samples_leaf=9, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=76, min_samples_leaf=9, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=81, min_samples_leaf=19, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=81, min_samples_leaf=19, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=81, min_samples_leaf=19, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=81, min_samples_leaf=19, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=81, min_samples_leaf=19, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=18, min_samples_leaf=19, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=18, min_samples_leaf=19, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=18, min_samples_leaf=19, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=18, min_samples_leaf=19, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=18, min_samples_leaf=19, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=89, min_samples_leaf=12, min_samples_split=19; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=30, min_samples_leaf=19, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=47, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=47, min_samples_leaf=7, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=60, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=22, min_samples_leaf=6, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=22, min_samples_leaf=6, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=42, min_samples_leaf=8, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=87, min_samples_leaf=12, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=53, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=53, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=35, min_samples_leaf=13, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=35, min_samples_leaf=13, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=57, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=57, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=57, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=57, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=90, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=90, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=90, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=34, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=78, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=78, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=78, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=78, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=88, min_samples_leaf=15, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=39, min_samples_leaf=15, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=39, min_samples_leaf=15, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=39, min_samples_leaf=15, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=39, min_samples_leaf=15, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=39, min_samples_leaf=15, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=95, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=95, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=96, min_samples_leaf=13, min_samples_split=13; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=96, min_samples_leaf=13, min_samples_split=13; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=96, min_samples_leaf=13, min_samples_split=13; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=96, min_samples_leaf=13, min_samples_split=13; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=86, min_samples_leaf=18, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=86, min_samples_leaf=18, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=86, min_samples_leaf=18, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=86, min_samples_leaf=18, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=44, min_samples_leaf=19, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=44, min_samples_leaf=19, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=44, min_samples_leaf=19, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=82, min_samples_leaf=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=82, min_samples_leaf=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=82, min_samples_leaf=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=82, min_samples_leaf=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=82, min_samples_leaf=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=58, min_samples_leaf=16, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=58, min_samples_leaf=16, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=73, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=73, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=73, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=73, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=73, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=55, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=55, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=55, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=55, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=55, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=25, min_samples_leaf=16, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=25, min_samples_leaf=16, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=25, min_samples_leaf=16, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=25, min_samples_leaf=16, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=28, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=52, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=52, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=52, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=52, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=51, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=30, min_samples_leaf=1, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=30, min_samples_leaf=1, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=36, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=36, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=36, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=95, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=12, min_samples_leaf=3, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=3, max_leaf_nodes=12, min_samples_leaf=3, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=33, min_samples_leaf=17, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=60, min_samples_leaf=4, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=60, min_samples_leaf=4, min_samples_split=11; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=22, min_samples_leaf=6, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=22, min_samples_leaf=6, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=58, min_samples_leaf=7, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=58, min_samples_leaf=7, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=87, min_samples_leaf=12, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=87, min_samples_leaf=12, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=13, min_samples_leaf=15, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=13, min_samples_leaf=15, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=98, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=12, max_leaf_nodes=98, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=19, min_samples_leaf=17, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=19, min_samples_leaf=17, min_samples_split=17; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=94, min_samples_leaf=17, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=94, min_samples_leaf=17, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=94, min_samples_leaf=17, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=94, min_samples_leaf=17, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=47, min_samples_leaf=16, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=47, min_samples_leaf=16, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_leaf=6, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_leaf=6, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=31, min_samples_leaf=16, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=31, min_samples_leaf=16, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=31, min_samples_leaf=16, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=6, max_leaf_nodes=31, min_samples_leaf=16, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=88, min_samples_leaf=15, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=88, min_samples_leaf=15, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=88, min_samples_leaf=15, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=88, min_samples_leaf=15, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=26, min_samples_leaf=18, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=26, min_samples_leaf=18, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=26, min_samples_leaf=18, min_samples_split=14; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=47, min_samples_leaf=15, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=47, min_samples_leaf=15, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=47, min_samples_leaf=15, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=47, min_samples_leaf=15, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, max_leaf_nodes=47, min_samples_leaf=15, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=18, min_samples_leaf=10, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=18, min_samples_leaf=10, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=18, min_samples_leaf=10, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=18, min_samples_leaf=10, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=18, min_samples_leaf=10, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=24, min_samples_leaf=1, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=24, min_samples_leaf=1, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=24, min_samples_leaf=1, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=24, min_samples_leaf=1, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=11, max_leaf_nodes=24, min_samples_leaf=1, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=26, min_samples_leaf=19, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=26, min_samples_leaf=19, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=26, min_samples_leaf=19, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=26, min_samples_leaf=19, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=7, max_leaf_nodes=26, min_samples_leaf=19, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=77, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=25, min_samples_leaf=16, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=71, min_samples_leaf=16, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=71, min_samples_leaf=16, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=71, min_samples_leaf=16, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=71, min_samples_leaf=16, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=4, max_leaf_nodes=71, min_samples_leaf=16, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=21, min_samples_leaf=6, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=21, min_samples_leaf=6, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=21, min_samples_leaf=6, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=21, min_samples_leaf=6, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=5, max_leaf_nodes=21, min_samples_leaf=6, min_samples_split=16; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=93, min_samples_leaf=16, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=93, min_samples_leaf=16, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=93, min_samples_leaf=16, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=93, min_samples_leaf=16, min_samples_split=18; total time=   0.0s
# [CV] END max_depth=13, max_leaf_nodes=93, min_samples_leaf=16, min_samples_split=18; total time=   0.0s
